# %% [markdown]
# # Exercise 1

# %%
# %matplotlib widget

import matplotlib.pyplot as plt
import numpy as np
import math
import scipy
from scipy import stats

def CalcAB(mean:float, variance:float) -> tuple[float, float]:
    b = mean + math.sqrt(3)*math.sqrt(variance)
    a = mean - math.sqrt(3)*math.sqrt(variance)
    return [a, b]
def UniformSequence(mean:float, variance:float, n:int):
    a, b = CalcAB(mean, variance)
    seq = np.random.uniform(a, b, n)
    return seq

meanABC = 2
varianceABC = 2
nABC = 100

def GenSequencesABCD(n, mean, variance):
    seqA = UniformSequence(mean, variance, n)
    
    
    seqB = np.random.normal(mean, math.sqrt(variance), n)
    
    
    seqC = np.random.laplace(mean, math.sqrt(0.5*variance), n)
    
    seqD = stats.cauchy.rvs(loc=2, scale=1, size=100)

    return seqA, seqB, seqC, seqD 
    
seqA, seqB, seqC, seqD = GenSequencesABCD(nABC, meanABC, varianceABC)

print("A mean: " + str(np.mean(seqA)))
print("A variance: " + str(np.var(seqA)))

print("B mean: " + str(np.mean(seqB)))
print("B variance: " + str(np.var(seqB)))

print("C mean: " + str(np.mean(seqC)))
print("C variance: " + str(np.var(seqC)))

def DrawSequenceMeanVariance(seq, name, color, ymn=-3, ymx=7):
    fig = plt.figure()
    plt.axis((0, len(seq), ymn, ymx))
    plt.xlabel("x")
    plt.ylabel("y")
    plt.plot(seq, color + ".", label="value");
    plt.axhline(np.mean(seq), color = color, linestyle = "-",\
                label="mean=" + str(round(np.mean(seq), 3)))
    plt.axhline(np.var(seq), color = color, linestyle = "--",\
                label="variance=" + str(round(np.var(seq), 3)))
    plt.title(name)
    plt.legend(title=name)
    
DrawSequenceMeanVariance(seqA, "Uniform Distrobution A", "b")
DrawSequenceMeanVariance(seqB, "Gaussian Distrobution B", "r")
DrawSequenceMeanVariance(seqC, "Laplace Distrobution C", "g")
# Out:
# A mean: 2.1519149941323423
# A variance: 2.2356231675489178
# B mean: 2.0173503110289324
# B variance: 1.7692194015068634
# C mean: 1.8291037339063132
# C variance: 1.849531631681617
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Exercise 2

# %%
print("D mean: " + str(np.mean(seqD)))
print("D variance: " + str(np.var(seqD)))
DrawSequenceMeanVariance(seqD, "Cauchy Distribution D", "b", min(seqD) * 1.05, max(seqD) * 1.05)
# Out:
# D mean: 2.6824490908347887
# D variance: 15.561953845770702
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Exercise 3

# %%
ns = [100, 1000, 10000, 100000]
resultsmean = [[], [], [], []]
resultsvar = [[], [], [], []]
for n in ns:
    seqs = GenSequencesABCD(n, meanABC, varianceABC)
    i = 0
    for seq in seqs:
        resultsmean[i].append(np.mean(seq))
        resultsvar[i].append(np.var(seq))
        i+=1
distnames = ["A", "B", "C", "D"]
distcolors = ["r", "g", "b", "y"]

fig = plt.figure()
plt.xlabel("Samples")
plt.ylabel("mean, variance")
plt.xscale('log')
for i in range(0, 3):
    plt.plot(ns, resultsmean[i], distcolors[i] + "o", label=distnames[i] + " mean")
    plt.plot(ns, resultsvar[i], distcolors[i] + "+", label=distnames[i] + " variance")
    #print(distnames[i], str(resultsmean[i]), str(resultsvar[i]))
plt.axhline(2, color = 'k', linestyle = "--", label="y=2.0", alpha=0.5)
plt.legend()

fig = plt.figure()
plt.xlabel("Samples")
plt.ylabel("mean, variance")
plt.xscale('log')
i = 3
plt.plot(ns, resultsmean[i], distcolors[i] + "o", label=distnames[i] + " mean")
plt.plot(ns, resultsvar[i], distcolors[i] + "+", label=distnames[i] + " variance")
plt.axhline(2, color = 'k', linestyle = "--", label="y=2.0", alpha=0.5)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Exercise 4
